# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

apple = pd.read_csv("G:/Data Science ML AI/Python files/Projects/Code_Along_Mobile_App_Data_Analysis/AppleStore.csv")
apple.head(20)
# Out:
#     Unnamed: 0         id                                         track_name  \
# 0            1  281656475                                    PAC-MAN Premium
# 1            2  281796108                          Evernote - stay organized
# 2            3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3            4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4            5  282935706                                              Bible
# 5            6  283619399                                   Shanghai Mahjong
# 6            7  283646709             PayPal - Send and request money safely
# 7            8  284035177                            Pandora - Music & Radio
# 8            9  284666222                        PCalc - The Best Calculator
# 9           10  284736660                                        Ms. PAC-MAN
# 10          11  284791396                          Solitaire by MobilityWare
# ...

# %%
#Drop the unnecessary columns

apple.drop(columns = ['Unnamed: 0'], inplace = True)
apple.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %%
#Basic data study

apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 16 columns):
# id                  7197 non-null int64
# track_name          7197 non-null object
# size_bytes          7197 non-null int64
# currency            7197 non-null object
# price               7197 non-null float64
# rating_count_tot    7197 non-null int64
# rating_count_ver    7197 non-null int64
# user_rating         7197 non-null float64
# user_rating_ver     7197 non-null float64
# ver                 7197 non-null object
# cont_rating         7197 non-null object
# prime_genre         7197 non-null object
# sup_devices.num     7197 non-null int64
# ipadSc_urls.num     7197 non-null int64
# lang.num            7197 non-null int64
# vpp_lic             7197 non-null int64
# dtypes: float64(3), int64(8), object(5)
# memory usage: 899.7+ KB

# %%
#describing the dataset

apple.describe()
# Out:
#                  id    size_bytes        price  rating_count_tot  \
# count  7.197000e+03  7.197000e+03  7197.000000      7.197000e+03
# mean   8.631310e+08  1.991345e+08     1.726218      1.289291e+04
# std    2.712368e+08  3.592069e+08     5.833006      7.573941e+04
# min    2.816565e+08  5.898240e+05     0.000000      0.000000e+00
# 25%    6.000937e+08  4.692275e+07     0.000000      2.800000e+01
# 50%    9.781482e+08  9.715302e+07     0.000000      3.000000e+02
# 75%    1.082310e+09  1.819249e+08     1.990000      2.793000e+03
# max    1.188376e+09  4.025970e+09   299.990000      2.974676e+06
#
#        rating_count_ver  user_rating  user_rating_ver  sup_devices.num  \
# count       7197.000000  7197.000000      7197.000000      7197.000000
# mean         460.373906     3.526956         3.253578        37.361817
# std         3920.455183     1.517948         1.809363         3.737715
# min            0.000000     0.000000         0.000000         9.000000
# ...

# %%
#Create a new column 'payment_type' and categorize all the applications into 'free' or 'paid'

# Custom function to classify an app as free or paid
def free_paid(x):
    if x > 0.00:
        return 'paid'
    else:
        return 'free'
    
#Creating new column as per requirement

apple['payment_type'] = apple['price'].apply(lambda x: free_paid(x))

apple.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %%
#another way to create payment type column

import numpy as np
apple['payment_type_1'] = np.where(apple['price'] > 0.00,'Paid','Free')
apple.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %%
#Number of free apps should be extremly high when compared to paid apps. Lets do a reality check
# A countplot to check the number of free and paid apps

sns.countplot(x=apple['payment_type'],data=apple)

# %%
#In which price range do most of the paid apps below 50 dollars fall?
# creating a subset for only the paid apps
df = apple[apple['price'] != 0]

# Setting plot details
plt.figure(figsize = (15,10))
plt.style.use("fivethirtyeight")

# creating a subset of the data below 50 dollars and plotting the data
dfa = df[df['price'] < 49.99]

plt.xlabel('Price($)')

dfa['price'].plot(kind = 'hist', log = True)

# %%
#Which category of 'prime_genre' most of the apps fall under?
plt.figure(figsize = (15,10))

sns.countplot(y = apple['prime_genre'],data = apple)

# %%
#Find the top 5 "prime_genre' in terms of count. Are the paid apps for these genres good enough?

#Finding the top 5 genres

top_genre = apple['prime_genre'].value_counts().sort_values(ascending=False)
top_genre.head()
# Out:
# Games            3862
# Entertainment     535
# Education         453
# Photo & Video     349
# Utilities         248
# Name: prime_genre, dtype: int64

# %%
top_5_genre = top_genre[:5].index
top_5_genre
# Out:
# Index(['Games', 'Entertainment', 'Education', 'Photo & Video', 'Utilities'], dtype='object')

# %%
top_genre_df = apple[apple['prime_genre'].isin(top_5_genre)]
top_genre_df.head(10)
# Out:
#            id                            track_name  size_bytes currency  \
# 0   281656475                       PAC-MAN Premium   100788224      USD
# 5   283619399                      Shanghai Mahjong    10485713      USD
# 8   284666222           PCalc - The Best Calculator    49250304      USD
# 9   284736660                           Ms. PAC-MAN    70023168      USD
# 10  284791396             Solitaire by MobilityWare    49618944      USD
# 11  284815117                      SCRABBLE Premium   227547136      USD
# 12  284815942  Google – Search made just for mobile   179979264      USD
# 14  284862767                              FreeCell    55153664      USD
# 19  285005463         Crash Bandicoot Nitro Kart 3D    10735026      USD
# 21  285994151                           :) Sudoku +     6169600      USD
#
#     price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0    3.99             21292                26          4.0              4.5
# ...

# %%
# plotting a violin plot to understand the ratings
plt.figure(figsize = (20,15))
plt.ylim(0,5)
sns.violinplot(data = top_genre_df, y = 'user_rating', x = 'prime_genre', hue = 'payment_type', split = True, scale = 'count', 
               palette = ['#44a8c5','#5fc497'])
plt.style.use("fast")
plt.xlabel('Categories')
plt.ylabel('User Rating')
plt.title('User Rating Distribution')
plt.show()

# %%
#Create a new column "size_mb" converting bytes to megabytes. For the applications below 50 dollars, does the price of the app increases with the increase in its size?

# Converting bytes to megabytes
def size(x):
    mb = x/1000000
    return mb

top_genre_df['size_mb'] = apple['size_bytes'].apply(lambda x: size(x))
top_genre_df.head()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            id                   track_name  size_bytes currency  price  \
# 0   281656475              PAC-MAN Premium   100788224      USD   3.99
# 5   283619399             Shanghai Mahjong    10485713      USD   0.99
# 8   284666222  PCalc - The Best Calculator    49250304      USD   9.99
# 9   284736660                  Ms. PAC-MAN    70023168      USD   3.99
# 10  284791396    Solitaire by MobilityWare    49618944      USD   4.99
#
#     rating_count_tot  rating_count_ver  user_rating  user_rating_ver     ver  \
# 0              21292                26          4.0              4.5   6.3.5
# ...

# %%
# creating a scatter plot to get our answer
plt.figure(figsize = (15,10))
paid_apps_desc = top_genre_df[top_genre_df['price'] < 50]

sns.lmplot(data = paid_apps_desc, x='size_mb',y='price',col='prime_genre',col_wrap=3,aspect=1.5,scatter=True,fit_reg=False,
          hue='prime_genre',legend_out=True,palette = ['#c973d0' , '#8e52b8' , '#4a4f92', '#4a73ab' , '#649ca1'])

# %%
#Can we create a recommendation column based on "user_rating" and "rating_count_tot"?


def recommendation(total_reviews,rating):
# creating an empty list to store the recommendation
    recommendation = []
# Iterating through all the rating and review count values, using the if else statement and categorizing the app
    for review_count,avg_rating in zip(apple['rating_count_tot'],apple['user_rating']):
        if review_count > total_reviews and avg_rating > rating:
            recommendation.append('yes')
        else:
            recommendation.append('no')

# %%
# Creating a new recommendation column
apple['recommendation'] = recommendation

# %%
recommendation(20000,3.5)

# %%
apple.head(10)
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
# 5  283619399                                   Shanghai Mahjong    10485713
# 6  283646709             PayPal - Send and request money safely   227795968
# 7  284035177                            Pandora - Music & Radio   130242560
# 8  284666222                        PCalc - The Best Calculator    49250304
# 9  284736660                                        Ms. PAC-MAN    70023168
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# ...
